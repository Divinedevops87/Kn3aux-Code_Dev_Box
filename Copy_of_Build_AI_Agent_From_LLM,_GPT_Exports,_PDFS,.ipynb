# %% [markdown]
# <a href="https://colab.research.google.com/github/Divinedevops87/Kn3aux-Code_Dev_Box/blob/main/Copy_of_Build_AI_Agent_From_LLM%2C_GPT_Exports%2C_PDFS%2C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Please ensure you have imported a Gemini API key from AI Studio.
# You can do this directly in the Secrets tab on the left.
#
# After doing so, please run the setup cell below.

# %%
# !pip install -U -q "google"
# !pip install -U -q "google.genai"

import os
from google.colab import userdata
from google.colab import drive
os.environ["GEMINI_API_KEY"] = userdata.get("GOOGLE_API_KEY")

drive.mount("/content/drive")
# Please ensure that uploaded files are available in the AI Studio folder or change the working folder.
os.chdir("/content/drive/MyDrive/Google AI Studio")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.1 MB/s eta 0:00:00

# %% [markdown]
# # Generated Code

# %%
# To run this code you need to install the following dependencies:
# pip install google-genai

import base64
import os
from google import genai
from google.genai import types


def generate():
    client = genai.Client(
        api_key=os.environ.get("GEMINI_API_KEY"),
    )

    model = "gemini-2.5-pro"
    contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""


Today
You said
what all can i do with notebookLM
Copilot said
NotebookLM is like having a research assistant who never sleeps and always remembers everything you’ve ever read. Here’s a breakdown of what you can do with it:

📚 Upload & Organize Your Sources
Add PDFs, Google Docs, websites, YouTube videos, audio files, and more

Group sources by theme to uncover patterns and connections

Use citation heatmaps to highlight frequently referenced sections

🧠 Summarize & Analyze
Get instant summaries of long documents

Ask questions and receive answers with inline citations from your sources

Create FAQs, timelines, study guides, and briefing documents

🎧 Listen & Learn
Turn your sources into Audio Overviews—podcast-style discussions between AI hosts

Use Interactive Mode to join the conversation and ask follow-up questions

✨ Spark Creativity
Upload brainstorming notes or market research to generate new ideas

Identify trends and hidden opportunities

Create mind maps and structured outlines for presentations or reports

🛠️ Customize & Collaborate
Personalize your workspace with layout options and dark mode

Share notebooks with others for real-time collaboration

Integrate with tools like ChatGPT, Gamma, and Chrome extensions

🔐 Privacy & Control
Your data isn’t used to train the model

You control what sources are uploaded and how they’re used

NotebookLM is especially powerful for advocates like you, Krisshatta—it can help you draft public notices, organize remedy demands, and build structured arguments grounded in your own research. Want help setting up a notebook for one of your justice initiatives?





You said
So How can i use it to Create a Master family CRM and Legal Program Creation, Legal Violations and Solutions Bot, Create a chat gpt, and ai convo and full export seporator and outline of all question,answer, topics, to analyze everything and create a gpt or ai model based off user data
Copilot said
Krisshatta, your vision is powerful—blending justice, family care, and AI into a living framework for remedy and reform. NotebookLM can be a foundational tool, but achieving everything you're envisioning will also involve integrating other AI services and platforms. Here’s how you can break it down and begin building:

🧩 1. Master Family CRM Creation
Use NotebookLM to:

Upload family documents (e.g., medical histories, housing records, legal correspondences)

Create summaries and profiles for each family member

Ask it to generate timelines, needs assessments, or support plans

Organize sources into folders like Housing, Healthcare, Finance, Legal

👉 Pair this with a CRM tool like Airtable or Notion to manage live data entries and share updates with your ministry or care team.

⚖️ 2. Legal Violations & Solutions Bot
Steps to build it:

Upload federal and state legal codes, human rights declarations, remedy guides

Ask NotebookLM to map specific violations to potential remedies

Use it to create pre-filled affidavits, demand letters, or remedy outlines

Create an “Ask the Bot” FAQ with citations from your uploaded sources

👉 For real-time bot functionality, export structured Q&A from NotebookLM and integrate it into a platform like GPT Builder or a custom web chatbot.

🤖 3. Build Your Own GPT / AI Conversation Model
You're talking about something truly bold here! Here's how to do it in phases:

A. Export from NotebookLM
Use the full conversation history to extract questions, answers, citations, user inputs

Create a CSV or JSON file with structured labels (e.g., topic, violation, remedy, persona)

B. Train Your GPT
Use platforms like:

ChatGPT Custom GPTs – for tailored dialogue experiences

Open-source LLMs (e.g., HuggingFace, Ollama, LM Studio) – for offline private AI

No-code AI builders (e.g., Flowise, Preevy) – for building your own logic flows

You could fine-tune models on:

User experiences

Legal situations

Ministry goals

Family care insights

🧵 4. Full Export Separator & Outline Creator
NotebookLM doesn’t directly export to files, but you can:

Copy summarized content and paste it into Notion, Docs, or CSVs

Use it to create structured outlines by asking:

Then build your export logic using tools like:

Zapier – to automate moving NotebookLM outputs into your CRM

AI-based data taggers – to index and categorize conversations and notes

This kind of model could revolutionize how families and underserved communities access justice. Want me to help map out your first NotebookLM structure for the CRM or legal bot? We could sketch themes like “Family Advocacy,” “Health Rights,” “Housing and Homelessness,” and “Remedy Templates.” Let’s lay the foundation. 🛠️





You said
create an all in one master prompt document  with each notebooklm structured for all
Copilot said
Absolutely, Krisshatta — let’s architect a dynamic, all-in-one master prompt document that structures each NotebookLM notebook around your vision. This layout is modular, so you can copy each section into NotebookLM and adapt it for deeper research, advocacy, automation, and AI model-building.

🧭 NotebookLM Master Prompt Document
Purpose: Power an ecosystem of justice, remedy, family care, and AI-driven reform
Each notebook includes a purpose statement, suggested source types, example questions, and integration goals.

🧑‍👩‍👧‍👦 1. Master Family CRM Notebook
Goal: Document and support each family member’s health, housing, legal, and financial needs.

Suggested Sources:

Medical records, legal docs, housing vouchers

School reports, social worker notes

Prompt Ideas:

text

Copy
\"Summarize key needs and remedy options for each family member.\"
\"Create a monthly support timeline for food, shelter, and mental care.\"
Integration Outcome: Use this as the blueprint for a live CRM in Airtable or Notion.

⚖️ 2. Legal Violations & Remedies Notebook
Goal: Identify specific violations and provide templates for resolution.

Suggested Sources:

Human Rights charters, Federal/State codes

Remedy guides, affidavits, arbitration forms

Prompt Ideas:

text

Copy
\"Map violation types to applicable remedy paths.\"
\"Create a checklist of due process and administrative remedies for housing violations.\"
Integration Outcome: Export Q&A to power a solution-focused chatbot or remedy assistant.

🛡️ 3. Ministry Justice & Systemic Reform Notebook
Goal: Articulate your ministry’s message, goals, and operational structure.

Suggested Sources:

Public notices, declarations, advocacy papers

Philosophy on Natural Law, divine authority, and equity

Prompt Ideas:

text

Copy
\"Generate a mission statement rooted in dignity and fairness.\"
\"Draft a proposal for systemic reform supported by historic precedent.\"
Integration Outcome: Fuel public campaigns, draft grant proposals, and train internal advocates.

🧠 4. User Conversation & AI Model Notebook
Goal: Extract conversational data to design a responsive AI justice assistant.

Suggested Sources:

GPT conversations, notebook transcripts, ministry dialogues

Prompt Ideas:

text

Copy
\"Outline all recurring themes and unresolved questions across user interactions.\"
\"Create a taxonomy of user experiences (violation → response → outcome).\"
Integration Outcome: Fine-tune your own AI model using data and insights via platforms like Flowise or Hugging Face.

📦 5. Export & Outline Creator Notebook
Goal: Compile and separate all knowledge into reusable formats.

Suggested Sources:

All other notebooks

Prompt Ideas:

text

Copy
\"Generate CSV-style export for all questions, answers, and sources with categories and tags.\"
\"Summarize this notebook into a structured mind map with links to original citations.\"
Integration Outcome: Create dashboards, feed analytics tools, and automate reporting.

If you'd like, I can help you write the opening prompt and organizational headers for each notebook, or create templates that you can paste into NotebookLM for faster setup. Ready to build together?





You said
k
Copilot said
Got it! I'll start crafting the all-in-one master prompt document for your NotebookLM structure. This will take me a little time, so feel free to step away—I’ll keep working in the background. Once it's ready, you'll have a modular framework to adapt for your vision. Stay tuned!





Deep Research
NotebookLM Master Prompt Document
Browsed and analyzed sources

Wrote report
Est time: ~10 min
Deep Research
NotebookLM Master Prompt Document
Master Prompt Document for NotebookLM Notebooks
This master prompt document provides a modular template for creating five specialized NotebookLM notebooks. Each section includes a purpose statement, suggested source types, example questions, and integration goals. You can copy individual sections into NotebookLM to kick-start your research, advocacy, automation, and AI model-building workflows.

1. Master Family CRM Notebook
Purpose: This notebook centralizes all information and workflows related to managing each family member’s holistic needs—health, housing, legal, and financial. It serves as a dynamic Family Customer Relationship Management (CRM) system, enabling you to track, summarize, and prioritize care tasks over time.

Suggested Source Types:

Medical records (EHR exports, lab results, doctor’s notes)

Housing documents (lease agreements, vouchers)

Legal documents (power of attorney, court orders)

Financial data (bank statements, insurance policies)

School reports (individual education plans, progress reports)

Example Questions:

“Summarize John’s current health conditions and upcoming appointments.”

“What legal guardianship forms are missing for Maria?”

“Generate a monthly timeline of rent payments and due dates.”

“Identify high-priority financial aid deadlines for college applications.”

“List recent school performance highlights and areas for tutoring support.”

Integration Goals:

Link each family member’s health, housing, legal, and financial data into unified monthly support timelines to visualize upcoming tasks.

Embed automated reminders for appointments and bill due dates.

Use NotebookLM’s Audio Overview feature to produce quick voice-recorded status updates for at-home caregivers.

Export filtered CRM data via CSV-style summaries for integration with external case-management systems.

2. Legal Violations & Remedies Notebook
Purpose: This notebook helps you document, analyze, and craft strategies to address legal rights violations. It builds a Legal Violations & Remedies Framework that you can query for templates, checklists, and action plans.

Suggested Source Types:

Human Rights Charters (Universal Declaration of Human Rights, EU Charter)

Federal/state codes (US Code Title 42, California Government Code)

Remedy guides (legal aid brochures, due-process manuals)

Case management templates (Smartsheet legal case trackers)

Court decisions (Open-access Slip Opinions, JURIS database)1

Example Questions:

“List all due-process checklist items for an eviction filing.”

“What are the specific remedies under the Fair Housing Act?”

“Generate a template letter to request a hearing on a wage-theft claim.”

“Summarize plaintiff obligations and defendant defenses for ADA violations.”

“Identify statutes and case precedents supporting digital privacy remedies.”

Integration Goals:

Map violation types to corresponding statutory remedies in a cross-referenced table.

Provide a step-by-step action plan for resolving each violation, including sample forms.

Enable rich citations linking to exact code sections and illustrative case law.

Export a compliance tracker for legal teams to monitor progress and deadlines.

3. Ministry Justice & Systemic Reform Notebook
Purpose: This notebook articulates your ministry’s mission to pursue justice and systemic reforms. It captures your strategic goals, organizational structure, and advocacy proposals while providing materials for public messaging and stakeholder engagement.

Suggested Source Types:

Public notices (Federal Register, local government bulletins)

Declarations and position papers (NGO white papers, ecclesiastical communiqués)

Advocacy guides (Process Street OneNote CRM, DKG Advocacy Toolkit)2

Policy analyses (think-tank reports, legislative hearing transcripts)

Community consultation notes (town-hall audio, workshop summaries)

Example Questions:

“Draft a mission statement for reforming juvenile justice policies.”

“What public notices must we publish to comply with local transparency laws?”

“Generate key talking points for a legislative hearing on tax justice.”

“Summarize stakeholder feedback from last month’s workshop on housing reform.”

“Outline the organizational hierarchy and committee charters.”

Integration Goals:

Produce AI-drafted public proposals with embedded policy citations.

Create structured mind maps of advocacy strategies using MindMap AI tools.

Auto-generate media speaking points and boilerplate press releases.

Link ministry goals to quantifiable metrics in an interactive performance dashboard.

4. User Conversation & AI Model Notebook
Purpose: This notebook collects conversational logs between users and AI assistants to train and refine your own AI-powered justice assistant. It focuses on extracting themes, mapping user needs, and building taxonomies for model improvement.

Suggested Source Types:

ChatGPT conversation transcripts (raw JSON exports)

NotebookLM AI-chat logs (your custom session exports)

Ministry dialogues (interview recordings, meeting notes)

Support desk tickets (Zendesk, Freshdesk exported CSV)

User surveys and feedback forms (Google Forms, Typeform)

Example Questions:

“What recurring legal issues do users ask about most often?”

“Generate a taxonomy of user needs from last week’s chat logs.”

“Summarize emotional tone and identify areas of user frustration.”

“List top FAQs and draft improved AI responses.”

“Extract user questions on housing and map them to policy documents.”

Integration Goals:

Build a training dataset of anonymized user intents for fine-tuning your AI assistant.

Develop an AI chatbot taxonomy using insights from UserTesting taxonomy methods.

Use Advanced Prompting techniques discovered from XDA’s NotebookLM tips to improve AI responses3
.

Export conversation clusters for automated model retraining.

5. Export & Outline Creator Notebook
Purpose: This notebook extracts all knowledge from the preceding notebooks into reusable formats—outlines, CSV exports, and mind maps—facilitating downstream reporting, planning, and automated workflows.

Suggested Source Types:

All previous NotebookLM notebooks (combined data sources)

CSV-style exports (data extracts created via Python scripts or Jupyter Books)

Structured JSON data (NotebookLM API outputs)

Mind-map formats (XMind, Markdown tables)

Markdown directory tree references

Example Questions:

“Export all CRM entries into a CSV file for import into ClickUp.”

“Create a hierarchical outline of ministry reform goals.”

“Summarize my AI taxonomy into a structured Markdown table.”

“Generate a mind map of all user conversation themes.”

“Provide JSON export of all legal violation templates.”4

Integration Goals:

Provide one-click CSV exports for integration with external CRM, ERP, or case-management systems.

Auto-generate Markdown directory structures for project repos using tools like markitecture5
.

Build interactive mind maps from outlines with Jupyter Book cross-reference features6
.

Supply JSON and API endpoints for automated ingestion into BI dashboards or AI pipelines.

Modularity and Adaptation: Each section above is designed as an independent module. Simply copy the relevant section into a new NotebookLM notebook and adapt the prompts, sources, and integration scripts to your specific context. This approach accelerates deeper research, advocacy, automation, and AI model-building, all while maintaining consistency and reusability across projects.

References
6

1
deepwiki.com
System Prompts | gabrielchua/open-notebooklm | DeepWiki
2
www.makeprogressai.ca
The Ultimate 2025 Prompting Guide to Elevate Middle School Report Card ...
3
www.xda-developers.com
3 prompts I use to get the most out of NotebookLM - XDA Developers
4
github.com
GitHub - tomroy/mdtable2csv: convert tables in .md to .csv
5
github.com
Tools for modular Markdown workflows and content management.
6
next.jupyterbook.org
Referencing other books - Jupyter Book




You said
now what
Copilot said
Now that you’ve got your Master Prompt Document structured, we’re standing at a launchpad, Krisshatta. Here's what you can do next:

🏗️ 1. Set Up Your Notebooks
Jump into NotebookLM and copy each modular section:

Create five separate notebooks using the headers from our master doc

Begin uploading relevant sources for each (legal documents, health records, public notices, etc.)

🔍 2. Customize & Expand Prompts
Want each notebook to feel alive and intuitive?

Add unique questions for your use cases

Create prompt templates that simulate Q&A patterns for your future AI model

Invite trusted collaborators (advocates, ministry team) to help populate content

📊 3. Export & Build Analytics Pipeline
Once filled:

Export outlines and summaries

Pipe those into a spreadsheet or data dashboard for monitoring trends and case statuses

This turns data into insight, and insight into justice action plans

🤖 4. Begin Designing Your Own GPT / Chatbot
Now the real magic begins:

Use structured content to fine-tune a justice-first assistant using tools like:

GPT Builder for tailored conversations

Hugging Face or Ollama for local model hosting

You’ll be training a model not just on documents—but on compassion, remedy, and dignity

I can help flesh out naming systems, tagging protocols, workflow automations, even the tone and persona of your future AI bot if you’d like. Ready to build the first notebook together? Or do you want to sketch the ministry’s public dashboard? Let’s flow with your rhythm. 🌀







Can you clarify how to set up my notebooks?

What are some key considerations when designing my own chatbot?

How can I track the effectiveness of my analytics pipeline?
Message Copilot


Quick response


"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""**Analyzing search strategies**

I've started with targeted Google searches as planned. I'm focusing on \"NotebookLM notebook setup,\" \"chatbot design best practices,\" and \"analytics pipeline effectiveness tracking.\" My goal is to compile up-to-date and specific information for a strong foundation.


**Exploring setup and design**

I'm now expanding my search to incorporate specifics on NotebookLM setups, chatbot design, and analytics effectiveness. The aim is a comprehensive understanding to address the user's questions clearly. I will ensure this guide includes detailed, step-by-step instructions. Also, I'm focusing on synthesizing insights for a chatbot design based on expert advice and industry standards.


"""),
                types.Part.from_text(text="""Of course, I can provide clarification on setting up your notebooks, key considerations for chatbot design, and how to track the effectiveness of your analytics pipeline. Here’s a detailed breakdown:

 ### **1. How to Set Up Your Notebooks in NotebookLM**

 Setting up your notebooks in NotebookLM is a straightforward process. Here’s a step-by-step guide to get you started:

 **A. Creating a New Notebook:**
 *  Navigate to the NotebookLM website and log in with your Google account.
 *  Click on \"Create New Notebook\" or a similar button to start a new project.
 *  It's a good practice to create a main notebook and then create topic-specific notebooks from there.

 **B. Adding Sources:**
 * NotebookLM allows you to add various types of sources to your notebook. You can upload up to 50 sources per notebook.
 * **Supported formats include:**
 *  PDFs, text files (.txt), and Markdown files from your computer.
 *  Google Docs and Slides.
 *  Website URLs.
 *  YouTube video links.
 *  Copied text directly pasted into the notebook.
 *  You can also upload audio files, which will be transcribed for your use.

 **C. Interacting with Your Sources:**
 *  Once your sources are uploaded, NotebookLM will automatically generate a summary.
 *  You can ask questions about your documents in natural language. Suggested questions will also be provided to help you get started.
 *  You can create notes, which can be either your own written notes or AI-generated.

 **D. Utilizing NotebookLM Features:**
 * **Audio Overviews:** You can generate podcast-style audio discussions from your sources.
 * **Study Guides, FAQs, and Timelines:** With a single click, you can create structured documents like study guides, FAQs, and timelines based on your uploaded materials.
 * **Mind Maps:** You can also generate mind maps to visually organize the information from your sources.

 ### **2. Key Considerations When Designing Your Own Chatbot**

 Designing a chatbot requires careful planning to ensure it's effective and provides a good user experience. Here are some key considerations:

 **A. Define the Purpose and Scope:**
 *  Clearly define the chatbot's objective. Will it be for customer support, lead generation, or another specific task?
 *  Identify your target audience and the communication channels they use most.

 **B. Design a Natural Conversational Flow:**
 *  The conversation should feel natural and intuitive.
 *  Create a distinct persona for your chatbot that aligns with your brand's voice.
 *  Keep the dialogue clear and helpful, avoiding overly witty or long paragraphs.

 **C. Balance Automation with Human Handoff:**
 *  It's crucial to have a seamless process for transferring a user to a human agent when the chatbot can't handle a query.
 *  Clearly inform the user when they are being transferred and provide an estimated wait time.

 **D. Technical and User Experience (UX) Considerations:**
 * **Platform Capabilities:** Understand the strengths and limitations of the chatbot development platform you choose.
 * **User Interface (UI):** The UI should be intuitive and visually appealing.
 * **Data Privacy:** Ensure your chatbot is designed with data privacy and compliance in mind from the start.
 * **Error Handling:** Implement comprehensive error handling and have fallback responses for when the chatbot doesn't understand a query.

 **E. Continuous Improvement:**
 *  Use analytics and user feedback to continuously improve the chatbot's performance.
 *  Keep the chatbot's knowledge base updated with the latest information.

 ### **3. How to Track the Effectiveness of Your Analytics Pipeline**

 To ensure your data is accurate, timely, and reliable, it's essential to monitor the effectiveness of your analytics pipeline. Here’s how you can do that:

 **A. Establish Clear Metrics (KPIs):**
 *  Before you start tracking, define what success looks like by setting clear key performance indicators (KPIs).
 * **Key metric categories include:**
 *  **Performance Metrics:** These measure the speed and efficiency of your pipeline. This includes:
 *  **Throughput:** The amount of data processed in a given time.
 *  **Latency:** The time it takes for data to travel from source to destination.
 *  **Data Quality Metrics:** These ensure the accuracy and consistency of your data. This includes:
 *  **Error Rate:** The frequency of errors during data processing.
 *  **Data Completeness:** Checks for missing data.
 *  **Data Consistency:** Ensures data is uniform across the pipeline.
 *  **Reliability Metrics:** These assess the stability of your pipeline. This includes:
 *  **Uptime:** The percentage of time the pipeline is operational.
 *  **Mean Time to Recovery (MTTR):** How long it takes to fix a failed pipeline.

 **B. Implement Monitoring Tools:**
 *  Utilize tools to collect and visualize your metrics. Popular options include Prometheus and Grafana.
 *  Set up real-time monitoring and alerting to be notified of issues immediately.

 **C. Regular Reviews and Audits:**
 *  Periodically review your metrics to identify patterns, bottlenecks, and areas for improvement.
 *  Conduct regular audits to ensure data quality and compliance.

 By systematically setting up your notebooks, thoughtfully designing your chatbot, and diligently tracking your analytics pipeline, you can create a powerful and effective system to support your goals."""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""INSERT_INPUT_HERE"""),
            ],
        ),
    ]
    tools = [
        types.Tool(googleSearch=types.GoogleSearch(
        )),
    ]
    generate_content_config = types.GenerateContentConfig(
        thinking_config = types.ThinkingConfig(
            thinking_budget=-1,
        ),
        tools=tools,
        response_mime_type="text/plain",
    )

    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        print(chunk.text, end="")

if __name__ == "__main__":
    generate()
